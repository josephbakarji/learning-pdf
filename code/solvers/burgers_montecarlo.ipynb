# %%
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)

import numpy as np
import matplotlib.pyplot as plt
from pdfsolver import PdfSolver, PdfGrid
from Learning import PDElearn
from datamanage import DataIO
from montecarlo import MCprocessing
from visualization import Visualize
import matplotlib.pyplot as plt

from scipy.signal import savgol_filter
from sklearn.metrics import mean_squared_error
import time
from __init__ import *

# %% [markdown]
# This code takes a set of monte Carlo simulations of Burgers' equation and sees how well the fit is based on the number of realizations

# %%
# Setup
num_realizations = 800
nu = 150 # Discretization in U dimension
distribution = 'CDF'
dMC = 100
MCvec = np.arange(50, num_realizations, dMC)
savefilename = 'burgers0' + str(num_realizations) + '.npy'
case='burgersMC'

# %%
coefvec = []
featurenamesvec = []
trainRMSEvec = []
testRMSEvec = []
trainScorevec = []
testScorevec = []

MCprocess = MCprocessing(savefilename)
for idx, MCcount in enumerate(MCvec):
    fu, gridvars, ICparams = MCprocess.buildKDE(nu, partial_data=True, MCcount=MCcount, save=False, plot=False, distribution=distribution)

    grid = PdfGrid(gridvars)
    difflearn = PDElearn(grid=grid, fu=fu, ICparams=ICparams, scase=case, trainratio=0.8, debug=False, verbose=True)
    coef, featurenames, trainRMSE, testRMSE, trainScore, testScore = difflearn.fit_sparse(feature_opt='1storder', \
            variableCoef=True, variableCoefBasis='simple_polynomial', variableCoefOrder=1, \
            use_sindy=True, sindy_alpha=0.001, shuffle=False)
    
    coefvec.append(coef) 
    featurenamesvec.append(featurenames)
    trainRMSEvec.append(trainRMSE)
    testRMSEvec.append(testRMSE)
    trainScorevec.append(trainScore) 
    testScorevec.append(testScore)
# Out:
# Variable coefficient type: simple_polynomial
#
#
# Sindy iteration : 0
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.968
# Train MSE 	= 2.123e-03
# ---- Coefficients ----
# fu_^{00} 	:	 0.000000000
# fu_^{01} 	:	 -0.000000000
# fu_^{10} 	:	 0.000000000
# fu_^{11} 	:	 -0.000000000
# fu_U^{00} 	:	 0.000000000
# fu_U^{01} 	:	 0.000022358
# fu_U^{10} 	:	 0.000000000
# fu_U^{11} 	:	 0.000000000
# fu_x^{00} 	:	 -0.165198214
# fu_x^{01} 	:	 -0.060706227
# fu_x^{10} 	:	 -0.831774559
# fu_x^{11} 	:	 -0.000000000
# fu_xx^{00} 	:	 -0.000000000
# fu_xx^{01} 	:	 -0.000000000
# fu_xx^{10} 	:	 0.015101219
# fu_xx^{11} 	:	 0.000000000
# fu_UU^{00} 	:	 -0.000000000
# fu_UU^{01} 	:	 0.000000000
# fu_UU^{10} 	:	 -0.001070297
# fu_UU^{11} 	:	 -0.000000000
# fu_xUU^{00} 	:	 0.000000000
# fu_xUU^{01} 	:	 -0.000000000
# fu_xUU^{10} 	:	 -0.000000000
# fu_xUU^{11} 	:	 -0.002225170
# fu_xU^{00} 	:	 -0.000000000
# fu_xU^{01} 	:	 -0.000000000
# fu_xU^{10} 	:	 -0.001291909
# fu_xU^{11} 	:	 -0.019417021
# fu_xxU^{00} 	:	 0.001100549
# fu_xxU^{01} 	:	 0.000311483
# fu_xxU^{10} 	:	 0.000000000
# fu_xxU^{11} 	:	 0.000873474
# fu_1^{00} 	:	 0.000000000
# fu_1^{01} 	:	 0.000000000
# fu_1^{10} 	:	 0.000000000
# fu_1^{11} 	:	 -0.000000000
# fu_xxx^{00} 	:	 0.000000000
# fu_xxx^{01} 	:	 0.000000000
# fu_xxx^{10} 	:	 0.000000000
# fu_xxx^{11} 	:	 0.000000000
# ---- Sparsity = 40 / 40
#
#
# Sindy iteration : 1
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.965
# Train MSE 	= 2.322e-03
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.179300584
# fu_x^{01} 	:	 -0.066813675
# fu_x^{10} 	:	 -0.809662336
# fu_xx^{10} 	:	 0.014900553
# fu_UU^{10} 	:	 -0.003128394
# fu_xUU^{11} 	:	 -0.001204069
# fu_xU^{10} 	:	 -0.012507995
# fu_xU^{11} 	:	 -0.002418387
# fu_xxU^{00} 	:	 0.002100268
# ---- Sparsity = 9 / 40
#
# #############################
#
# Features option: 1storder
# ---- Errors ----
# Train Score 	= 0.965
# Test Score 	= 0.915
# Train RMSE 	= 4.819e-02
# Test RMSE 	= 4.028e-02
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.179300584
# fu_x^{01} 	:	 -0.066813675
# fu_x^{10} 	:	 -0.809662336
# fu_xx^{10} 	:	 0.014900553
# fu_UU^{10} 	:	 -0.003128394
# fu_xUU^{11} 	:	 -0.001204069
# fu_xU^{10} 	:	 -0.012507995
# fu_xU^{11} 	:	 -0.002418387
# fu_xxU^{00} 	:	 0.002100268
# ---- Sparsity = 9 / 40
# Variable coefficient type: simple_polynomial
#
#
# Sindy iteration : 0
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.980
# Train MSE 	= 1.170e-03
# ---- Coefficients ----
# fu_^{00} 	:	 0.000000000
# fu_^{01} 	:	 0.000000000
# fu_^{10} 	:	 0.000000000
# fu_^{11} 	:	 0.000000000
# fu_U^{00} 	:	 0.000000000
# fu_U^{01} 	:	 0.000000000
# fu_U^{10} 	:	 0.000000000
# fu_U^{11} 	:	 0.000000000
# fu_x^{00} 	:	 -0.099524306
# fu_x^{01} 	:	 -0.015709779
# fu_x^{10} 	:	 -0.904561975
# fu_x^{11} 	:	 -0.000000000
# fu_xx^{00} 	:	 0.000000000
# fu_xx^{01} 	:	 -0.000000000
# fu_xx^{10} 	:	 0.015107610
# fu_xx^{11} 	:	 0.000000000
# fu_UU^{00} 	:	 0.000000000
# fu_UU^{01} 	:	 0.000000000
# fu_UU^{10} 	:	 -0.000000000
# fu_UU^{11} 	:	 0.000000000
# fu_xUU^{00} 	:	 0.000055180
# fu_xUU^{01} 	:	 -0.000000000
# fu_xUU^{10} 	:	 0.000000000
# fu_xUU^{11} 	:	 -0.000443768
# fu_xU^{00} 	:	 -0.000000000
# fu_xU^{01} 	:	 -0.000000000
# fu_xU^{10} 	:	 -0.000000000
# fu_xU^{11} 	:	 -0.006421870
# fu_xxU^{00} 	:	 0.000683028
# fu_xxU^{01} 	:	 0.000199258
# fu_xxU^{10} 	:	 0.000000000
# fu_xxU^{11} 	:	 0.000714576
# fu_1^{00} 	:	 0.000000000
# fu_1^{01} 	:	 0.000000000
# fu_1^{10} 	:	 0.000000000
# fu_1^{11} 	:	 0.000000000
# fu_xxx^{00} 	:	 0.000000000
# fu_xxx^{01} 	:	 -0.000000000
# fu_xxx^{10} 	:	 -0.000000000
# fu_xxx^{11} 	:	 -0.000000000
# ---- Sparsity = 40 / 40
#
#
# Sindy iteration : 1
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.967
# Train MSE 	= 1.959e-03
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.151033277
# fu_x^{01} 	:	 -0.032755688
# fu_x^{10} 	:	 -0.840296421
# fu_xx^{10} 	:	 0.014639106
# fu_xU^{11} 	:	 0.008843383
# ---- Sparsity = 5 / 40
#
# #############################
#
# Features option: 1storder
# ---- Errors ----
# Train Score 	= 0.967
# Test Score 	= 0.929
# Train RMSE 	= 4.426e-02
# Test RMSE 	= 2.207e-02
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.151033277
# fu_x^{01} 	:	 -0.032755688
# fu_x^{10} 	:	 -0.840296421
# fu_xx^{10} 	:	 0.014639106
# fu_xU^{11} 	:	 0.008843383
# ---- Sparsity = 5 / 40
# Variable coefficient type: simple_polynomial
#
#
# Sindy iteration : 0
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.982
# Train MSE 	= 8.316e-04
# ---- Coefficients ----
# fu_^{00} 	:	 0.000000000
# fu_^{01} 	:	 0.000000000
# fu_^{10} 	:	 0.000498722
# fu_^{11} 	:	 0.000000000
# fu_U^{00} 	:	 0.000000000
# fu_U^{01} 	:	 0.000000000
# fu_U^{10} 	:	 0.000000000
# fu_U^{11} 	:	 0.000000000
# fu_x^{00} 	:	 -0.104453880
# fu_x^{01} 	:	 -0.015983077
# fu_x^{10} 	:	 -0.892802351
# fu_x^{11} 	:	 -0.000000000
# fu_xx^{00} 	:	 0.000000000
# fu_xx^{01} 	:	 0.000000000
# fu_xx^{10} 	:	 0.014851839
# fu_xx^{11} 	:	 0.000000000
# fu_UU^{00} 	:	 -0.000000000
# fu_UU^{01} 	:	 0.000000000
# fu_UU^{10} 	:	 -0.000000000
# fu_UU^{11} 	:	 0.000000000
# fu_xUU^{00} 	:	 0.000000000
# fu_xUU^{01} 	:	 -0.000000000
# fu_xUU^{10} 	:	 0.000000000
# fu_xUU^{11} 	:	 -0.000257019
# fu_xU^{00} 	:	 -0.000000000
# fu_xU^{01} 	:	 -0.000000000
# fu_xU^{10} 	:	 -0.000000000
# fu_xU^{11} 	:	 -0.000976443
# fu_xxU^{00} 	:	 0.000622698
# fu_xxU^{01} 	:	 0.000000000
# fu_xxU^{10} 	:	 0.000103796
# fu_xxU^{11} 	:	 0.000666874
# fu_1^{00} 	:	 0.000000000
# fu_1^{01} 	:	 0.000000000
# fu_1^{10} 	:	 0.000000000
# fu_1^{11} 	:	 0.000000000
# fu_xxx^{00} 	:	 -0.000000000
# fu_xxx^{01} 	:	 -0.000000000
# fu_xxx^{10} 	:	 -0.000000000
# fu_xxx^{11} 	:	 -0.000000000
# ---- Sparsity = 40 / 40
#
#
# Sindy iteration : 1
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.971
# Train MSE 	= 1.330e-03
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.092117943
# fu_x^{01} 	:	 -0.025762968
# fu_x^{10} 	:	 -0.900257481
# fu_xx^{10} 	:	 0.014898691
# ---- Sparsity = 4 / 40
#
# #############################
#
# Features option: 1storder
# ---- Errors ----
# Train Score 	= 0.971
# Test Score 	= 0.915
# Train RMSE 	= 3.647e-02
# Test RMSE 	= 1.949e-02
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.092117943
# fu_x^{01} 	:	 -0.025762968
# fu_x^{10} 	:	 -0.900257481
# fu_xx^{10} 	:	 0.014898691
# ---- Sparsity = 4 / 40
# Variable coefficient type: simple_polynomial
#
#
# Sindy iteration : 0
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.985
# Train MSE 	= 6.811e-04
# ---- Coefficients ----
# fu_^{00} 	:	 0.000000000
# fu_^{01} 	:	 0.000000000
# fu_^{10} 	:	 0.000695448
# fu_^{11} 	:	 0.000000000
# fu_U^{00} 	:	 0.000000000
# fu_U^{01} 	:	 0.000000000
# fu_U^{10} 	:	 0.000000000
# fu_U^{11} 	:	 0.000000000
# fu_x^{00} 	:	 -0.107055307
# fu_x^{01} 	:	 -0.013966069
# fu_x^{10} 	:	 -0.887616988
# fu_x^{11} 	:	 -0.000000000
# fu_xx^{00} 	:	 0.000000000
# fu_xx^{01} 	:	 0.000000000
# fu_xx^{10} 	:	 0.014906417
# fu_xx^{11} 	:	 0.000000000
# fu_UU^{00} 	:	 -0.000000000
# fu_UU^{01} 	:	 0.000000000
# fu_UU^{10} 	:	 -0.000000000
# fu_UU^{11} 	:	 0.000000000
# fu_xUU^{00} 	:	 0.000000000
# fu_xUU^{01} 	:	 -0.000000000
# fu_xUU^{10} 	:	 0.000000000
# fu_xUU^{11} 	:	 -0.000009079
# fu_xU^{00} 	:	 -0.000000000
# fu_xU^{01} 	:	 -0.000000000
# fu_xU^{10} 	:	 -0.000000000
# fu_xU^{11} 	:	 -0.000016347
# fu_xxU^{00} 	:	 0.000580137
# fu_xxU^{01} 	:	 0.000105886
# fu_xxU^{10} 	:	 0.000169545
# fu_xxU^{11} 	:	 0.000474518
# fu_1^{00} 	:	 0.000000000
# fu_1^{01} 	:	 0.000000000
# fu_1^{10} 	:	 0.000000000
# fu_1^{11} 	:	 0.000000000
# fu_xxx^{00} 	:	 -0.000000000
# fu_xxx^{01} 	:	 -0.000000000
# fu_xxx^{10} 	:	 -0.000000000
# fu_xxx^{11} 	:	 -0.000000000
# ---- Sparsity = 40 / 40
#
#
# Sindy iteration : 1
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.977
# Train MSE 	= 1.074e-03
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.094373807
# fu_x^{01} 	:	 -0.022723612
# fu_x^{10} 	:	 -0.895518199
# fu_xx^{10} 	:	 0.014815731
# ---- Sparsity = 4 / 40
#
# #############################
#
# Features option: 1storder
# ---- Errors ----
# Train Score 	= 0.977
# Test Score 	= 0.920
# Train RMSE 	= 3.277e-02
# Test RMSE 	= 1.573e-02
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.094373807
# fu_x^{01} 	:	 -0.022723612
# fu_x^{10} 	:	 -0.895518199
# fu_xx^{10} 	:	 0.014815731
# ---- Sparsity = 4 / 40
# Variable coefficient type: simple_polynomial
#
#
# Sindy iteration : 0
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.987
# Train MSE 	= 5.997e-04
# ---- Coefficients ----
# fu_^{00} 	:	 0.000000000
# fu_^{01} 	:	 0.000000000
# fu_^{10} 	:	 0.000599765
# fu_^{11} 	:	 0.000000000
# fu_U^{00} 	:	 0.000000000
# fu_U^{01} 	:	 0.000000000
# fu_U^{10} 	:	 0.000004902
# fu_U^{11} 	:	 0.000000000
# fu_x^{00} 	:	 -0.096365530
# fu_x^{01} 	:	 -0.016970622
# fu_x^{10} 	:	 -0.894949076
# fu_x^{11} 	:	 -0.000000000
# fu_xx^{00} 	:	 0.000000000
# fu_xx^{01} 	:	 0.000000000
# fu_xx^{10} 	:	 0.014919407
# fu_xx^{11} 	:	 0.000000000
# fu_UU^{00} 	:	 -0.000000000
# fu_UU^{01} 	:	 0.000000000
# fu_UU^{10} 	:	 -0.000000000
# fu_UU^{11} 	:	 0.000000000
# fu_xUU^{00} 	:	 0.000000000
# fu_xUU^{01} 	:	 -0.000000000
# fu_xUU^{10} 	:	 0.000000000
# fu_xUU^{11} 	:	 -0.000000000
# fu_xU^{00} 	:	 -0.000000000
# fu_xU^{01} 	:	 -0.000000000
# fu_xU^{10} 	:	 -0.000000000
# fu_xU^{11} 	:	 -0.000000000
# fu_xxU^{00} 	:	 0.000511240
# fu_xxU^{01} 	:	 0.000185918
# fu_xxU^{10} 	:	 0.000235265
# fu_xxU^{11} 	:	 0.000345208
# fu_1^{00} 	:	 0.000000000
# fu_1^{01} 	:	 0.000000000
# fu_1^{10} 	:	 0.000000000
# fu_1^{11} 	:	 0.000000000
# fu_xxx^{00} 	:	 -0.000000000
# fu_xxx^{01} 	:	 -0.000000000
# fu_xxx^{10} 	:	 -0.000000000
# fu_xxx^{11} 	:	 -0.000000000
# ---- Sparsity = 40 / 40
# Sindy iteration : 1
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.980
# Train MSE 	= 9.237e-04
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.085716265
# fu_x^{01} 	:	 -0.024104558
# fu_x^{10} 	:	 -0.900419149
# fu_xx^{10} 	:	 0.014869672
# ---- Sparsity = 4 / 40
#
# #############################
#
# Features option: 1storder
# ---- Errors ----
# Train Score 	= 0.980
# Test Score 	= 0.915
# Train RMSE 	= 3.039e-02
# Test RMSE 	= 1.434e-02
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.085716265
# fu_x^{01} 	:	 -0.024104558
# fu_x^{10} 	:	 -0.900419149
# fu_xx^{10} 	:	 0.014869672
# ---- Sparsity = 4 / 40
# Variable coefficient type: simple_polynomial
#
#
# Sindy iteration : 0
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.989
# Train MSE 	= 5.277e-04
# ---- Coefficients ----
# fu_^{00} 	:	 0.000000000
# fu_^{01} 	:	 0.000000000
# fu_^{10} 	:	 0.000554764
# fu_^{11} 	:	 0.000000000
# fu_U^{00} 	:	 0.000000000
# fu_U^{01} 	:	 0.000000000
# fu_U^{10} 	:	 0.000000000
# fu_U^{11} 	:	 0.000000000
# fu_x^{00} 	:	 -0.093542303
# fu_x^{01} 	:	 -0.015567871
# fu_x^{10} 	:	 -0.898115670
# fu_x^{11} 	:	 -0.000000000
# fu_xx^{00} 	:	 0.000000000
# fu_xx^{01} 	:	 0.000000000
# fu_xx^{10} 	:	 0.014753722
# fu_xx^{11} 	:	 0.000000000
# fu_UU^{00} 	:	 -0.000000000
# fu_UU^{01} 	:	 0.000000000
# fu_UU^{10} 	:	 -0.000000000
# fu_UU^{11} 	:	 0.000000000
# fu_xUU^{00} 	:	 0.000000000
# fu_xUU^{01} 	:	 -0.000000000
# fu_xUU^{10} 	:	 0.000000000
# fu_xUU^{11} 	:	 -0.000000000
# fu_xU^{00} 	:	 0.000000000
# fu_xU^{01} 	:	 -0.000000000
# fu_xU^{10} 	:	 -0.000000000
# fu_xU^{11} 	:	 -0.000000000
# fu_xxU^{00} 	:	 0.000586586
# fu_xxU^{01} 	:	 0.000051929
# fu_xxU^{10} 	:	 0.000028902
# fu_xxU^{11} 	:	 0.000503259
# fu_1^{00} 	:	 0.000000000
# fu_1^{01} 	:	 0.000000000
# fu_1^{10} 	:	 0.000000000
# fu_1^{11} 	:	 0.000000000
# fu_xxx^{00} 	:	 -0.000000000
# fu_xxx^{01} 	:	 -0.000000000
# fu_xxx^{10} 	:	 -0.000000000
# fu_xxx^{11} 	:	 -0.000000000
# ---- Sparsity = 40 / 40
#
#
# Sindy iteration : 1
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.983
# Train MSE 	= 7.840e-04
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.084552559
# fu_x^{01} 	:	 -0.021475839
# fu_x^{10} 	:	 -0.902577948
# fu_xx^{10} 	:	 0.014686486
# ---- Sparsity = 4 / 40
#
# #############################
#
# Features option: 1storder
# ---- Errors ----
# Train Score 	= 0.983
# Test Score 	= 0.920
# Train RMSE 	= 2.800e-02
# Test RMSE 	= 1.306e-02
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.084552559
# fu_x^{01} 	:	 -0.021475839
# fu_x^{10} 	:	 -0.902577948
# fu_xx^{10} 	:	 0.014686486
# ---- Sparsity = 4 / 40
# Variable coefficient type: simple_polynomial
#
#
# Sindy iteration : 0
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.990
# Train MSE 	= 4.803e-04
# ---- Coefficients ----
# fu_^{00} 	:	 0.000000000
# fu_^{01} 	:	 0.000000000
# fu_^{10} 	:	 0.000495574
# fu_^{11} 	:	 0.000000000
# fu_U^{00} 	:	 0.000000000
# fu_U^{01} 	:	 0.000000000
# fu_U^{10} 	:	 0.000000000
# fu_U^{11} 	:	 0.000000000
# fu_x^{00} 	:	 -0.091418761
# fu_x^{01} 	:	 -0.014525797
# fu_x^{10} 	:	 -0.900252956
# fu_x^{11} 	:	 -0.000000000
# fu_xx^{00} 	:	 0.000000000
# fu_xx^{01} 	:	 0.000000000
# fu_xx^{10} 	:	 0.014639918
# fu_xx^{11} 	:	 0.000000000
# fu_UU^{00} 	:	 -0.000000000
# fu_UU^{01} 	:	 0.000000000
# fu_UU^{10} 	:	 -0.000000000
# fu_UU^{11} 	:	 0.000000000
# fu_xUU^{00} 	:	 0.000000000
# fu_xUU^{01} 	:	 -0.000000000
# fu_xUU^{10} 	:	 0.000000000
# fu_xUU^{11} 	:	 -0.000000000
# fu_xU^{00} 	:	 0.000000000
# fu_xU^{01} 	:	 -0.000000000
# fu_xU^{10} 	:	 -0.000000000
# fu_xU^{11} 	:	 -0.000000000
# fu_xxU^{00} 	:	 0.000343161
# fu_xxU^{01} 	:	 0.000247108
# fu_xxU^{10} 	:	 0.000285807
# fu_xxU^{11} 	:	 0.000231345
# fu_1^{00} 	:	 0.000000000
# fu_1^{01} 	:	 0.000000000
# fu_1^{10} 	:	 0.000000000
# fu_1^{11} 	:	 0.000000000
# fu_xxx^{00} 	:	 -0.000000000
# fu_xxx^{01} 	:	 -0.000000000
# fu_xxx^{10} 	:	 -0.000000000
# fu_xxx^{11} 	:	 -0.000000000
# ---- Sparsity = 40 / 40
#
#
# Sindy iteration : 1
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.985
# Train MSE 	= 6.866e-04
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.085687075
# fu_x^{01} 	:	 -0.019431783
# fu_x^{10} 	:	 -0.901890753
# fu_xx^{10} 	:	 0.014579432
# ---- Sparsity = 4 / 40
#
# #############################
#
# Features option: 1storder
# ---- Errors ----
# Train Score 	= 0.985
# Test Score 	= 0.924
# Train RMSE 	= 2.620e-02
# Test RMSE 	= 1.185e-02
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.085687075
# fu_x^{01} 	:	 -0.019431783
# fu_x^{10} 	:	 -0.901890753
# fu_xx^{10} 	:	 0.014579432
# ---- Sparsity = 4 / 40
# Variable coefficient type: simple_polynomial
#
#
# Sindy iteration : 0
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.991
# Train MSE 	= 4.413e-04
# ---- Coefficients ----
# fu_^{00} 	:	 0.000000000
# fu_^{01} 	:	 0.000000000
# fu_^{10} 	:	 0.000353397
# fu_^{11} 	:	 0.000000000
# fu_U^{00} 	:	 0.000000000
# fu_U^{01} 	:	 0.000000000
# fu_U^{10} 	:	 0.000000000
# fu_U^{11} 	:	 0.000000000
# fu_x^{00} 	:	 -0.085695425
# fu_x^{01} 	:	 -0.015288848
# fu_x^{10} 	:	 -0.904867145
# fu_x^{11} 	:	 -0.000000000
# fu_xx^{00} 	:	 0.000000000
# fu_xx^{01} 	:	 0.000000000
# fu_xx^{10} 	:	 0.014603877
# fu_xx^{11} 	:	 0.000000000
# fu_UU^{00} 	:	 -0.000000000
# fu_UU^{01} 	:	 0.000000000
# fu_UU^{10} 	:	 -0.000000000
# fu_UU^{11} 	:	 0.000000000
# fu_xUU^{00} 	:	 0.000000000
# fu_xUU^{01} 	:	 -0.000000000
# fu_xUU^{10} 	:	 0.000000000
# fu_xUU^{11} 	:	 -0.000000000
# fu_xU^{00} 	:	 0.000000000
# fu_xU^{01} 	:	 -0.000000000
# fu_xU^{10} 	:	 -0.000000000
# fu_xU^{11} 	:	 -0.000047110
# fu_xxU^{00} 	:	 0.000264913
# fu_xxU^{01} 	:	 0.000315079
# fu_xxU^{10} 	:	 0.000290044
# fu_xxU^{11} 	:	 0.000208065
# fu_1^{00} 	:	 0.000000000
# fu_1^{01} 	:	 0.000000000
# fu_1^{10} 	:	 0.000000000
# fu_1^{11} 	:	 0.000000000
# fu_xxx^{00} 	:	 -0.000000000
# fu_xxx^{01} 	:	 -0.000000000
# fu_xxx^{10} 	:	 -0.000000000
# fu_xxx^{11} 	:	 -0.000000000
# ---- Sparsity = 40 / 40
#
#
# Sindy iteration : 1
#
# ##########
#
# ---- Errors ----
# Train Score 	= 0.986
# Train MSE 	= 6.296e-04
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.082034264
# fu_x^{01} 	:	 -0.019788620
# fu_x^{10} 	:	 -0.904476906
# fu_xx^{10} 	:	 0.014534971
# ---- Sparsity = 4 / 40
#
# #############################
#
# Features option: 1storder
# ---- Errors ----
# Train Score 	= 0.986
# Test Score 	= 0.926
# Train RMSE 	= 2.509e-02
# Test RMSE 	= 1.099e-02
# ---- Coefficients ----
# fu_x^{00} 	:	 -0.082034264
# fu_x^{01} 	:	 -0.019788620
# fu_x^{10} 	:	 -0.904476906
# fu_xx^{10} 	:	 0.014534971
# ---- Sparsity = 4 / 40

# %%
trainRMSE
# Out:
# 0.02509224185226593

# %%
# plot
fig, ax = plt.subplots(1, 2)
ax[0].plot(MCvec, trainRMSEvec)
ax[0].plot(MCvec, testRMSEvec)
#ax[0].title('RMSE')
ax[0].set_xlabel('MC realizations')
ax[0].set_ylabel('RMSE')
ax[0].legend(['Train: < 0.7 T', 'Test: > 0.7 T'])

ax[1].plot(MCvec, trainScorevec)
ax[1].plot(MCvec, testScorevec)
#ax[1].title('score')
ax[1].set_xlabel('MC realizations')
ax[1].set_ylabel('Score')
ax[1].legend(['Train: < 0.7 T', 'Test: > 0.7 T'])

fig.set_size_inches(10.5, 4.5)
fig.savefig('rmse_mcrealizations')

plt.show()

# %%
data = {
'coefvec' : coefvec,
'featurenamesvec' : featurenamesvec, 
'trainRMSEvec' : trainRMSEvec,
'testRMSEvec' : testRMSEvec,
'trainScorevec' : trainScorevec,
'testScorevec' : testScorevec,
}
np.save('mc_burgers_cdf_numreal.npy', data)
